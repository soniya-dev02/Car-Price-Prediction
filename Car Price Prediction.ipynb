# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Car_Price_Prediction.csv")
df
# Out:
#        Make    Model  Year  Engine Size  Mileage Fuel Type Transmission  \
# 0     Honda  Model B  2015          3.9    74176    Petrol       Manual
# 1      Ford  Model C  2014          1.7    94799  Electric    Automatic
# 2       BMW  Model B  2006          4.1    98385  Electric       Manual
# 3     Honda  Model B  2015          2.6    88919  Electric    Automatic
# 4     Honda  Model C  2004          3.4   138482    Petrol    Automatic
# ..      ...      ...   ...          ...      ...       ...          ...
# 995  Toyota  Model D  2002          1.9     5445    Petrol       Manual
# 996   Honda  Model B  2020          3.1   149112    Diesel       Manual
# 997    Ford  Model C  2008          1.9   195387    Petrol    Automatic
# 998  Toyota  Model A  2003          4.4      246    Petrol    Automatic
# 999    Audi  Model C  2020          2.1    31153    Diesel    Automatic
#
#             Price
# 0    30246.207931
# 1    22785.747684
# 2    25760.290347
# 3    25638.003491
# ...

# %%
df.head()
# Out:
#     Make    Model  Year  Engine Size  Mileage Fuel Type Transmission  \
# 0  Honda  Model B  2015          3.9    74176    Petrol       Manual
# 1   Ford  Model C  2014          1.7    94799  Electric    Automatic
# 2    BMW  Model B  2006          4.1    98385  Electric       Manual
# 3  Honda  Model B  2015          2.6    88919  Electric    Automatic
# 4  Honda  Model C  2004          3.4   138482    Petrol    Automatic
#
#           Price
# 0  30246.207931
# 1  22785.747684
# 2  25760.290347
# 3  25638.003491
# 4  21021.386657

# %%
df.tail()
# Out:
#        Make    Model  Year  Engine Size  Mileage Fuel Type Transmission  \
# 995  Toyota  Model D  2002          1.9     5445    Petrol       Manual
# 996   Honda  Model B  2020          3.1   149112    Diesel       Manual
# 997    Ford  Model C  2008          1.9   195387    Petrol    Automatic
# 998  Toyota  Model A  2003          4.4      246    Petrol    Automatic
# 999    Audi  Model C  2020          2.1    31153    Diesel    Automatic
#
#             Price
# 995  22765.597091
# 996  30392.575567
# 997  16446.892292
# 998  27396.156708
# 999  31620.864907

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Size', 'Mileage', 'Fuel Type',
#        'Transmission', 'Price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Make          1000 non-null   object
#  1   Model         1000 non-null   object
#  2   Year          1000 non-null   int64
#  3   Engine Size   1000 non-null   float64
#  4   Mileage       1000 non-null   int64
#  5   Fuel Type     1000 non-null   object
#  6   Transmission  1000 non-null   object
#  7   Price         1000 non-null   float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#               Year  Engine Size       Mileage         Price
# count  1000.000000  1000.000000    1000.00000   1000.000000
# mean   2010.688000     2.798300   97192.48700  25136.615530
# std       6.288577     1.024137   59447.31576   5181.401368
# min    2000.000000     1.000000      56.00000   6704.953524
# 25%    2005.000000     1.900000   44768.75000  21587.878370
# 50%    2011.000000     2.800000   94411.50000  25189.325247
# 75%    2016.000000     3.700000  148977.75000  28806.368974
# max    2021.000000     4.500000  199867.00000  41780.504635

# %%
a=[ 'Make','Model','Fuel Type','Transmission'
         ]
for i in a:
    print("column:",i)
    print("unique values:")
    print(df[i].unique())
    print("value counts")
    print(df[i].value_counts())
# Out:
# column: Make
# unique values:
# ['Honda' 'Ford' 'BMW' 'Audi' 'Toyota']
# value counts
# Make
# Ford      225
# Audi      212
# Honda     198
# Toyota    187
# BMW       178
# Name: count, dtype: int64
# column: Model
# unique values:
# ['Model B' 'Model C' 'Model A' 'Model D' 'Model E']
# value counts
# Model
# Model B    212
# Model C    205
# Model A    202
# Model D    197
# Model E    184
# Name: count, dtype: int64
# column: Fuel Type
# unique values:
# ['Petrol' 'Electric' 'Diesel']
# value counts
# Fuel Type
# Diesel      344
# Petrol      331
# Electric    325
# Name: count, dtype: int64
# column: Transmission
# unique values:
# ['Manual' 'Automatic']
# value counts
# Transmission
# Manual       511
# Automatic    489
# Name: count, dtype: int64

# %%
#checking null values
print(df.isnull().sum())
# Out:
# Make            0
# Model           0
# Year            0
# Engine Size     0
# Mileage         0
# Fuel Type       0
# Transmission    0
# Price           0
# dtype: int64

# %%
print("minimum of Price:",np.min(df['Price']))
print("maximum of Price:",np.max(df['Price']))
# Out:
# minimum of Price: 6704.953523986209
# maximum of Price: 41780.5046353258

# %%
print("minimum of Mileage:",np.min(df['Mileage']))
print("maximum of Mileage:",np.max(df['Mileage']))
# Out:
# minimum of Mileage: 56
# maximum of Mileage: 199867

# %%
#visualizations
a=df['Make'].value_counts()
print(a)
print(type(a))
m=a.index
print(m)
n=a.values
print(n)
plt.bar(m,n)
plt.title("bar Graph")
plt.xlabel("Make")
plt.ylabel("counts")
plt.show()
# Out:
# Make
# Ford      225
# Audi      212
# Honda     198
# Toyota    187
# BMW       178
# Name: count, dtype: int64
# <class 'pandas.core.series.Series'>
# Index(['Ford', 'Audi', 'Honda', 'Toyota', 'BMW'], dtype='object', name='Make')
# [225 212 198 187 178]

# %%
x=df['Fuel Type'].value_counts()
work=['Petrol','Electric','Diesel']
m=[0.1,0,0]
plt.title("Different Fuel Type")
plt.pie(x,labels=work,colors=['pink','cyan','red'],explode=m,autopct="%1.2f%%")
plt.show()

# %%
a=df['Engine Size'].iloc[0:100]
plt.title("Engine Size variation")
plt.plot(a)
plt.show()

# %%
x=df['Year'].value_counts()
plt.hist(x,color='b',edgecolor='k')
plt.title('Year')
plt.show()

# %%
a=df['Price'].iloc[100:200]
b=df['Price'].iloc[0:100]
plt.title("Price variation")
plt.scatter(a,b,color='y')
plt.show()

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Size', 'Mileage', 'Fuel Type',
#        'Transmission', 'Price'],
#       dtype='object')

# %%
#nominal
#dummy encoding
import pandas as pd
df=pd.get_dummies(df,columns=['Make'],dtype='int')
df
# Out:
#        Model  Year  Engine Size  Mileage Fuel Type Transmission         Price  \
# 0    Model B  2015          3.9    74176    Petrol       Manual  30246.207931
# 1    Model C  2014          1.7    94799  Electric    Automatic  22785.747684
# 2    Model B  2006          4.1    98385  Electric       Manual  25760.290347
# 3    Model B  2015          2.6    88919  Electric    Automatic  25638.003491
# 4    Model C  2004          3.4   138482    Petrol    Automatic  21021.386657
# ..       ...   ...          ...      ...       ...          ...           ...
# 995  Model D  2002          1.9     5445    Petrol       Manual  22765.597091
# 996  Model B  2020          3.1   149112    Diesel       Manual  30392.575567
# 997  Model C  2008          1.9   195387    Petrol    Automatic  16446.892292
# 998  Model A  2003          4.4      246    Petrol    Automatic  27396.156708
# 999  Model C  2020          2.1    31153    Diesel    Automatic  31620.864907
#
# ...

# %%
#nominal
#dummy encoding
import pandas as pd
df=pd.get_dummies(df,columns=['Fuel Type'],dtype='int')
df
# Out:
#        Model  Year  Engine Size  Mileage Transmission         Price  \
# 0    Model B  2015          3.9    74176       Manual  30246.207931
# 1    Model C  2014          1.7    94799    Automatic  22785.747684
# 2    Model B  2006          4.1    98385       Manual  25760.290347
# 3    Model B  2015          2.6    88919    Automatic  25638.003491
# 4    Model C  2004          3.4   138482    Automatic  21021.386657
# ..       ...   ...          ...      ...          ...           ...
# 995  Model D  2002          1.9     5445       Manual  22765.597091
# 996  Model B  2020          3.1   149112       Manual  30392.575567
# 997  Model C  2008          1.9   195387    Automatic  16446.892292
# 998  Model A  2003          4.4      246    Automatic  27396.156708
# 999  Model C  2020          2.1    31153    Automatic  31620.864907
#
#      Make_Audi  Make_BMW  Make_Ford  Make_Honda  Make_Toyota  \
# 0            0         0          0           1            0
# ...

# %%
#nominal
#dummy encoding
import pandas as pd
df=pd.get_dummies(df,columns=['Model'],dtype='int')
df
# Out:
#      Year  Engine Size  Mileage Transmission         Price  Make_Audi  \
# 0    2015          3.9    74176       Manual  30246.207931          0
# 1    2014          1.7    94799    Automatic  22785.747684          0
# 2    2006          4.1    98385       Manual  25760.290347          0
# 3    2015          2.6    88919    Automatic  25638.003491          0
# 4    2004          3.4   138482    Automatic  21021.386657          0
# ..    ...          ...      ...          ...           ...        ...
# 995  2002          1.9     5445       Manual  22765.597091          0
# 996  2020          3.1   149112       Manual  30392.575567          0
# 997  2008          1.9   195387    Automatic  16446.892292          0
# 998  2003          4.4      246    Automatic  27396.156708          0
# 999  2020          2.1    31153    Automatic  31620.864907          1
#
#      Make_BMW  Make_Ford  Make_Honda  Make_Toyota  Fuel Type_Diesel  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['Transmission']=lb.fit_transform(df['Transmission'])
df
# Out:
#      Year  Engine Size  Mileage  Transmission         Price  Make_Audi  \
# 0    2015          3.9    74176             1  30246.207931          0
# 1    2014          1.7    94799             0  22785.747684          0
# 2    2006          4.1    98385             1  25760.290347          0
# 3    2015          2.6    88919             0  25638.003491          0
# 4    2004          3.4   138482             0  21021.386657          0
# ..    ...          ...      ...           ...           ...        ...
# 995  2002          1.9     5445             1  22765.597091          0
# 996  2020          3.1   149112             1  30392.575567          0
# 997  2008          1.9   195387             0  16446.892292          0
# 998  2003          4.4      246             0  27396.156708          0
# 999  2020          2.1    31153             0  31620.864907          1
#
#      Make_BMW  Make_Ford  Make_Honda  Make_Toyota  Fuel Type_Diesel  \
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Engine Size', 'Mileage', 'Transmission', 'Price', 'Make_Audi',
#        'Make_BMW', 'Make_Ford', 'Make_Honda', 'Make_Toyota',
#        'Fuel Type_Diesel', 'Fuel Type_Electric', 'Fuel Type_Petrol',
#        'Model_Model A', 'Model_Model B', 'Model_Model C', 'Model_Model D',
#        'Model_Model E'],
#       dtype='object')

# %%
x=df.drop('Price',axis=1)
y=df['Price']

# %%
x.columns
# Out:
# Index(['Year', 'Engine Size', 'Mileage', 'Transmission', 'Make_Audi',
#        'Make_BMW', 'Make_Ford', 'Make_Honda', 'Make_Toyota',
#        'Fuel Type_Diesel', 'Fuel Type_Electric', 'Fuel Type_Petrol',
#        'Model_Model A', 'Model_Model B', 'Model_Model C', 'Model_Model D',
#        'Model_Model E'],
#       dtype='object')

# %%
print(x.shape)
print(y.shape)
# Out:
# (1000, 17)
# (1000,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (800, 17)
# (200, 17)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (800,)
# (200,)

# %%
#Model training
#Linear regression
#1.import algorithm
from sklearn.linear_model import LinearRegression

#2.Object for class
#model
lr=LinearRegression()

# %%
#model traning
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr_result=lr.predict(x_test)
print(lr_result)
# Out:
# [25695.70851695 29413.29178922 26781.43215544 27492.50089816
#  27578.32713544 19648.8280689  23373.70778804 27229.57138935
#  30460.33116022 23952.07028605 28300.15914536 22333.51539845
#  18588.57276323 26200.47796076 24464.69049435 28189.12884293
#  21176.34359358 27691.3992946  24346.52294995 30787.77560305
#  21750.08194276 21962.42655405 16974.46973848 22952.20077101
#  16365.31112124 26229.23618555 28649.68688154 21095.67768059
#  22665.39719353 29625.5553907  19768.17743981 24123.87848306
#  22372.35947552 34552.56260804 29494.84877125 29445.81192602
#  18433.08011649 28885.87649596 30911.97125082 23846.58552812
#  30851.95813302 26336.43132638 29084.08043259 25479.5230512
#  21065.89222941 21142.89713087 32379.87723834 32631.8609409
#  24850.09824567 22145.61821559 31976.73835751 21063.34979529
#  24083.2018312  19067.24502208 21768.06559088 27043.06811675
#  15449.80589654 29763.98660781 26966.61762736 24682.35295498
# ...

# %%
#model evaluation
#checking results based on y_test

print("R^2 score for LR on training set:",lr.score(x_train,y_train))
print("R^2 score for LR on tesit set:",lr.score(x_test,y_test))


#checking for error(checking wrong prrediction)
from sklearn.metrics import mean_absolute_error as mae,mean_squared_error as mse

print("--linear regression--model evaluation--")
print("Mean Absolute Error(MAE):",mae(y_test,lr_result))
print("Mean Squared Error(MSE):",mse(y_test,lr_result))
print("Root Mean Squared Error(RMSE):",np.sqrt(mse(y_test,lr_result)))
# Out:
# R^2 score for LR on training set: 0.8457634186792121
# R^2 score for LR on tesit set: 0.8170961815663961
# --linear regression--model evaluation--
# Mean Absolute Error(MAE): 1810.5547575774983
# Mean Squared Error(MSE): 5005471.209260058
# Root Mean Squared Error(RMSE): 2237.291042591477

# %%
#Model training
#DecisionTreeRegressor
#1.import algorithm
from sklearn.tree import DecisionTreeRegressor

#2.Object for class
#model
dt=DecisionTreeRegressor()

# %%
#model traning
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt_result=dt.predict(x_test)
print(dt_result)
# Out:
# [28225.08185321 27413.65008271 28794.44897145 22932.25081189
#  25521.10745921 16421.91485308 24970.60376302 29339.94561326
#  32536.14887712 20813.96920048 31337.12983292 22519.39025009
#  19333.30421313 25210.96836868 26994.6787638  27101.14627061
#  16582.93551064 25230.31069933 26140.8533578  34716.9800197
#  22913.2282529  21021.38665739 21288.04375668 25246.75216412
#  16950.53851869 24544.36559654 26726.59549263 21860.27432529
#  23895.75456202 29680.57288346 22109.6662862  24030.54726178
#  23096.92351456 33036.50150827 32297.52894609 31648.72781951
#  12412.86477928 28305.72319861 29846.04658151 29609.06386426
#  29759.37055085 23591.142062   31648.72781951 25653.07861863
#  23096.92351456 20152.09690167 39203.51407329 32422.38985272
#  26708.68842683 21533.14900906 34637.41728588 16582.93551064
#  25686.3578772  20035.5788591  22464.83122876 26892.43672971
#  16950.53851869 29325.53777941 23005.61866635 30089.45617106
# ...

# %%
#model evaluation
#checking results based on y_test

print("R^2 score for DT on training set:",dt.score(x_train,y_train))
print("R^2 score for DT on tesit set:",dt.score(x_test,y_test))


#checking for error(checking wrong prrediction)
from sklearn.metrics import mean_absolute_error as mae,mean_squared_error as mse

print("--Decision Tree--model evaluation--")
print("Mean Absolute Error(MAE):",mae(y_test,dt_result))
print("Mean Squared Error(MSE):",mse(y_test,dt_result))
print("Root Mean Squared Error(RMSE):",np.sqrt(mse(y_test,dt_result)))
# Out:
# R^2 score for DT on training set: 1.0
# R^2 score for DT on tesit set: 0.6417477613445289
# --Decision Tree--model evaluation--
# Mean Absolute Error(MAE): 2553.6011930153227
# Mean Squared Error(MSE): 9804176.214581775
# Root Mean Squared Error(RMSE): 3131.1621188596696

# %%
#Model training
#DecisionTreeRegressor
#1.import algorithm
from sklearn.ensemble import RandomForestRegressor

#2.Object for class
#model
rf=RandomForestRegressor()
#model traning
rf.fit(x_train,y_train)

rf_result=rf.predict(x_test)
print(rf_result)
# Out:
# [25962.14344336 29740.60657339 27315.49499352 26443.87194757
#  28604.31187812 19201.79394614 22493.64990046 27445.46733697
#  30674.06560399 23400.84611511 29796.96392066 21706.0209488
#  18966.21770169 26303.53755757 26075.87638283 28398.36783505
#  20725.73910625 26991.4093794  24689.45600236 31299.88219089
#  23755.85818203 21059.68756127 17852.4502868  22663.25797733
#  18409.89303398 23745.95161681 27892.32825578 20904.17849303
#  24213.76347225 29543.16697838 18735.83484127 24395.0469498
#  23444.23454135 33946.86157739 29411.8004435  29588.17816442
#  16813.55489447 28859.13275787 30870.99719957 25701.69871454
#  30997.90117658 25405.22041024 29452.09136697 25185.22033602
#  22002.80686877 21752.96346808 32762.71567892 32847.51899713
#  25228.91239149 22504.86673106 33086.21072146 20739.57442946
#  23373.14333195 20714.71855813 22525.93736313 27784.3003702
#  16513.23338348 29580.49429985 27762.97399317 25384.27205592
# ...

# %%
#model evaluation
#checking results based on y_test

print("R^2 score for RF on training set:",rf.score(x_train,y_train))
print("R^2 score for RF on tesit set:",rf.score(x_test,y_test))


#checking for error(checking wrong prrediction)
from sklearn.metrics import mean_absolute_error as mae,mean_squared_error as mse

print("--Random Forest--model evaluation--")
print("Mean Absolute Error(MAE):",mae(y_test,rf_result))
print("Mean Squared Error(MSE):",mse(y_test,rf_result))
print("Root Mean SquaredError(RMSE):",np.sqrt(mse(y_test,rf_result)))
# Out:
# R^2 score for RF on training set: 0.972346937348024
# R^2 score for RF on tesit set: 0.7984965919003333
# --Random Forest--model evaluation--
# Mean Absolute Error(MAE): 1917.883007976445
# Mean Squared Error(MSE): 5514480.323311572
# Root Mean SquaredError(RMSE): 2348.2930658909618

# %%
#Model training
#DecisionTreeRegressor
#1.import algorithm
from sklearn.svm import SVR

#2.Object for class
#model
svm=SVR()
#model traning
svm.fit(x_train,y_train)
# Out:
# SVR()

# %%
svm_result=svm.predict(x_test)
print(svm_result)
# Out:
# [25244.35013474 25216.60563038 25245.32704128 25035.77560221
#  25201.61527029 25057.39608009 25115.86076452 25239.838761
#  25194.99294052 25245.31659861 25245.05778508 25007.16885809
#  25037.02460438 25187.69041866 25187.03368394 24995.55376676
#  25171.94713664 25042.30793387 24990.76695319 25046.25843653
#  25152.36077845 25059.92309055 24994.01352395 25108.14715991
#  25043.64003598 25143.17269878 25166.75495707 25219.11088692
#  25008.18007453 25245.24018521 25018.11803873 25162.53382683
#  25150.24444528 25245.25282309 25244.43812693 25238.25481552
#  24990.40992606 25182.22272187 25222.12189552 25189.93623082
#  25224.06026274 24993.54515758 25234.80926834 24992.58168735
#  25129.22135283 25231.0355867  25205.07942572 25244.70742619
#  25014.08308841 25061.38876013 25239.43198789 25163.25742897
#  25066.90708653 25099.1667447  25199.18199869 25240.30226057
#  25073.15096473 25219.98911698 24990.42903304 24990.41827402
# ...

# %%
#model evaluation
#checking results based on y_test

print("R^2 score for SVM on training set:",svm.score(x_train,y_train))
print("R^2 score for SVM on tesit set:",svm.score(x_test,y_test))


#checking for error(checking wrong prrediction)
from sklearn.metrics import mean_absolute_error as mae,mean_squared_error as mse

print("--SVM--model evaluation--")
print("Mean Absolute Error(MAE):",mae(y_test,svm_result))
print("Mean Squared Error(MSE):",mse(y_test,svm_result))
print("Root Mean Squared Error(RMSE):",np.sqrt(mse(y_test,svm_result)))
# Out:
# R^2 score for SVM on training set: 0.020445097153447334
# R^2 score for SVM on tesit set: 0.019081126468785903
# --SVM--model evaluation--
# Mean Absolute Error(MAE): 4330.89744798023
# Mean Squared Error(MSE): 26844497.955971695
# Root Mean Squared Error(RMSE): 5181.1676247706655

# %%
import joblib

#save model
joblib.dump(lr,'lr_car_price_prediction.pkl')

#save coumn structure(imp)
joblib.dump(x.columns.tolist(),'scaler_lr_model_car_price_prediction.pkl')

#save label encoder(for traffic_level)
joblib.dump(lr,"Transmission.pkl")

print("model saved successfully")
# Out:
# model saved successfully

# %%
x.columns
# Out:
# Index(['Year', 'Engine Size', 'Mileage', 'Transmission', 'Make_Audi',
#        'Make_BMW', 'Make_Ford', 'Make_Honda', 'Make_Toyota',
#        'Fuel Type_Diesel', 'Fuel Type_Electric', 'Fuel Type_Petrol',
#        'Model_Model A', 'Model_Model B', 'Model_Model C', 'Model_Model D',
#        'Model_Model E'],
#       dtype='object')

# %%
model=joblib.load('lr_car_price_prediction.pkl')
scaler=joblib.load('scaler_lr_model_car_price_prediction.pkl')

# %%
#Testing
Year=int(input("Enter the year:"))
Engine_Size=float(input("Enter the 'Engine Size'"))
Mileage=int(input("Enter the Mileage:"))
Transmission=input("Enter the Transmission(Automatic-0/Manual-1):")
Make=input("Enter the Make(Honda/Ford/BMW/Audi/Toyota):")
Fuel_Type=input("Enter the Fuel Type(Diesel/Electric/Petrol):")
Model=input("Enter the Model(Model A/Model B/Model C/Model D/Model E):")

if Transmission=='Automatic':
    Transmission=0
else:
    Transmission=1

Make_Audi,Make_BMW,Make_Ford,Make_Honda,Make_Toyota=0,0,0,0,0
if Make=='Audi':
   Make_Audi=1
elif Make=='BMW':
   Make_BMW=1
elif Make=='Ford':
   Make_Ford=1
elif Make=='Honda':
   Make_Honda=1    
else:
   Make_Toyota=1 

Model_Model_A,Model_Model_B, Model_Model_C,Model_Model_D,Model_Model_E=0,0,0,0,0
if Model=='Model A':
   Model_Model_A=1
elif Model=='Model B':
   Model_Model_B=1
elif Model=='Model C':
   Model_Model_C=1 
elif Model=='Model D':
   Model_Model_D=1    
else:
   Model_Model_E=1 

Fuel_Type_Diesel,Fuel_Type_Electric,Fuel_Type_Petrol=0,0,0
if Fuel_Type=='Diesel':
    Fuel_Type_Diesel=1
elif Fuel_Type=='Electric':
    Fuel_Type_Electric=1    
else:
     Fuel_Type_Petrol=1  

data=pd.DataFrame([[Year,Engine_Size,Mileage,Transmission,Make_Audi,Make_BMW,Make_Ford,Make_Honda,Make_Toyota,
                    Fuel_Type_Diesel,Fuel_Type_Electric,Fuel_Type_Petrol,
                    Model_Model_A,Model_Model_B, Model_Model_C,Model_Model_D,Model_Model_E]],
                  columns=['Year', 'Engine Size', 'Mileage', 'Transmission', 'Make_Audi',
       'Make_BMW', 'Make_Ford', 'Make_Honda', 'Make_Toyota',
       'Fuel Type_Diesel', 'Fuel Type_Electric', 'Fuel Type_Petrol',
       'Model_Model A', 'Model_Model B', 'Model_Model C', 'Model_Model D',
       'Model_Model E'])

result=model.predict(data)
print(result)
# Out:
# Enter the year: 2015
# Enter the 'Engine Size' 3.9
# Enter the Mileage: 74176
# Enter the Transmission(Automatic-0/Manual-1): Manual-1
# Enter the Make(Honda/Ford/BMW/Audi/Toyota): Honda
# Enter the Fuel Type(Diesel/Electric/Petrol): Petrol
# Enter the Model(Model A/Model B/Model C/Model D/Model E): Model B
# [30500.94539293]

# %%
df.tail(5)
# Out:
#      Year  Engine Size  Mileage  Transmission         Price  Make_Audi  \
# 995  2002          1.9     5445             1  22765.597091          0
# 996  2020          3.1   149112             1  30392.575567          0
# 997  2008          1.9   195387             0  16446.892292          0
# 998  2003          4.4      246             0  27396.156708          0
# 999  2020          2.1    31153             0  31620.864907          1
#
#      Make_BMW  Make_Ford  Make_Honda  Make_Toyota  Fuel Type_Diesel  \
# 995         0          0           0            1                 0
# 996         0          0           1            0                 1
# 997         0          1           0            0                 0
# 998         0          0           0            1                 0
# 999         0          0           0            0                 1
#
#      Fuel Type_Electric  Fuel Type_Petrol  Model_Model A  Model_Model B  \
# ...
